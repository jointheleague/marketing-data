# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import contextily as cx
from pathlib import Path
dd = Path('/workspaces/marketing-data/data')

# %%
schools = gpd.read_file(dd/ 'SCHOOL.zip')
schools.head()
# Out:
#                  district  schoolID priv          shrtName gsOffered  \
# 0   Sweetwater Union High         1    N  Bonita Vista Mid       7-8
# 1   Sweetwater Union High         2    N   Bonita Vista SH      9-12
# 2  Chula Vista Elementary         3    N        Clear View       K-6
# 3  Chula Vista Elementary         4    N           Tiffany       K-6
# 4  Chula Vista Elementary         5    N          McMillin       K-6
#
#                                 socType charter    openDate    zip  \
# 0  Intermediate/Middle Schools (Public)       N  1980-07-01  91910
# 1                 High Schools (Public)       N  1980-07-01  91913
# 2           Elementary Schools (Public)       N  1991-09-10  91910
# 3           Elementary Schools (Public)       N  1980-07-01  91913
# 4           Elementary Schools (Public)       N  2001-07-17  91913
#
#           city                    addr                            name  \
# 0  Chula Vista     650 Otay Lakes Road             Bonita Vista Middle
# 1  Chula Vista     751 Otay Lakes Road        Bonita Vista Senior High
# 2  Chula Vista        455 Windrose Way                      Clear View
# 3  Chula Vista    1691 Elmhurst Street  Tiffany (Burton C.) Elementary
# 4  Chula Vista  1201 Santa Cora Avenue     McMillin (Corky) Elementary
#
#           cdsCode                     docType                         geometry
# 0  37684116059745        High School District  POINT (6328948.010 1816631.100)
# 1  37684113730405        High School District  POINT (6331354.100 1815648.060)
# 2  37680236109771  Elementary School District  POINT (6317094.090 1815461.560)
# 3  37680236095020  Elementary School District  POINT (6333672.320 1815473.900)
# 4  37680236118988  Elementary School District  POINT (6335643.680 1810957.240)

# %%
#schools.gsOffered.unique() # How to get all of the grades

# Grade we are interested in. 
grades = ['7-8', '9-12', 'K-6', 'K-5', 'K-8', 'P-8', 'K-12', '7-12', '6-12',
       'P-6', '6-8', '11-12',  '5-6', '7-9', '4-6', '10-12', 
       '4-8', '1-12', '5-8',  '1-9',  '12', 'K-11', 
       '3-12', '9', '12-Adult', 'K-9', '8-12', '1-8']

#schools.socType.unique()
types = ['Intermediate/Middle Schools (Public)', 'High Schools (Public)',
       'Elementary Schools (Public)', 'Alternative Schools of Choice',
       'District Community Day Schools',
       'K-12 Schools (Public)',
       'Junior High Schools (Public)',
       'Private',
       'San Marcos Unified']

# %%
fig, ax = plt.subplots(1, 1, figsize=(6,15))  

t = schools.to_crs(epsg=3857) # Make it web mercator to match the basemap
t = t[t.gsOffered.isin(grades)]
t = t[t.socType.isin(types)]
t = t.cx[-1.307e7:-1.300e7, :]

t.plot(markersize=1, column='socType', legend=True, ax=ax)

cx.add_basemap(ax)
leg = ax.get_legend()                                                                         
leg.set_bbox_to_anchor((1, 1))                                                              
    
t.to_file(dd / "schools.geojson", driver='GeoJSON')
